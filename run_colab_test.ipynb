# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/MyDrive/Dacon_artist_classification'
# %cd '/content/drive/Othercomputers/내 노트북/Dacon_artist_classification'
# Out:
# /content/drive/Othercomputers/내 노트북/Dacon_artist_classification

# %%
# !pip install efficientnet_pytorch
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.7.1-py3-none-any.whl size=16446 sha256=a09c9155bd51c6c8090be8f6116dcdcf7aabb5c5bea68341cedc28526ba66c8c
#   Stored in directory: /root/.cache/pip/wheels/0e/cc/b2/49e74588263573ff778da58cc99b9c6349b496636a7e165be6
# Successfully built efficientnet-pytorch
# ...

# %%
# !python test.py --ckpt_dir ckpt --batch_size 8 --img_shape 500 --root_dir '/content/drive/Othercomputers/내 노트북/Dacon_artist_classification'
# Out:
# Downloading: "https://github.com/lukemelas/EfficientNet-PyTorch/releases/download/1.0/efficientnet-b0-355c32eb.pth" to /root/.cache/torch/hub/checkpoints/efficientnet-b0-355c32eb.pth
# 100% 20.4M/20.4M [00:03<00:00, 5.85MB/s]
# Loaded pretrained weights for efficientnet-b0
# Fold 0: 100% 1584/1584 [1:50:55<00:00,  4.20s/it]
# Loaded pretrained weights for efficientnet-b0
# Fold 1: 100% 1584/1584 [04:31<00:00,  5.83it/s]
# Loaded pretrained weights for efficientnet-b0
# Fold 2: 100% 1584/1584 [04:31<00:00,  5.84it/s]
# Loaded pretrained weights for efficientnet-b0
# Fold 3: 100% 1584/1584 [04:31<00:00,  5.84it/s]
# Loaded pretrained weights for efficientnet-b0
# Fold 4: 100% 1584/1584 [04:31<00:00,  5.84it/s]
