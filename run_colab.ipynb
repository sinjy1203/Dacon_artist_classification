# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !python '/content/drive/Othercomputers/내 노트북/Dacon_artist_classification/train.py' --epochs 100 --batch_size 32 \
--root_dir '/content/drive/Othercomputers/내 노트북/Dacon_artist_classification' --img_shape 300 --n_blocks 5
# Out:
# Fold 1 training
# Epoch 1: 100% 148/148 [21:51<00:00,  8.86s/it]
# Epoch 2: 100% 148/148 [02:34<00:00,  1.05s/it]
# Epoch 3: 100% 148/148 [02:34<00:00,  1.04s/it]
# EarlyStopping counter: 1 out of 5
# Epoch 4: 100% 148/148 [02:33<00:00,  1.04s/it]
# Epoch 5: 100% 148/148 [02:33<00:00,  1.04s/it]
# EarlyStopping counter: 1 out of 5
# Epoch 6: 100% 148/148 [02:35<00:00,  1.05s/it]
# EarlyStopping counter: 2 out of 5
# Epoch 7: 100% 148/148 [02:33<00:00,  1.04s/it]
# EarlyStopping counter: 3 out of 5
# Epoch 8: 100% 148/148 [02:32<00:00,  1.03s/it]
# EarlyStopping counter: 4 out of 5
# Epoch 9: 100% 148/148 [02:32<00:00,  1.03s/it]
# EarlyStopping counter: 5 out of 5
# Early stopping
# Fold 2 training
# Epoch 1: 100% 148/148 [02:32<00:00,  1.03s/it]
# Epoch 2: 100% 148/148 [02:32<00:00,  1.03s/it]
# EarlyStopping counter: 1 out of 5
# Epoch 3: 100% 148/148 [02:33<00:00,  1.03s/it]
# EarlyStopping counter: 2 out of 5
# Epoch 4: 100% 148/148 [02:32<00:00,  1.03s/it]
# ...
